# %%
import ibm_db

# %%
#Replace the placeholder values with your actual Db2 hostname, username, and password:
dsn_hostname = "dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net" # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_uid = "lfq69032"        # e.g. "abc12345"
dsn_pwd = "m17tv^kv460lg3tl"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_port = "50000"                # e.g. "50000" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create the dsn connection string
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

#print the connection string to check correct values are specified
print(dsn)
# Out:
# DRIVER={IBM DB2 ODBC DRIVER};DATABASE=BLUDB;HOSTNAME=dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net;PORT=50000;PROTOCOL=TCPIP;UID=lfq69032;PWD=m17tv^kv460lg3tl;

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create database connection

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  lfq69032 on host:  dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# %sql ibm_db_sa://lfq69032:m17tv^kv460lg3tl@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# 'Connected: lfq69032@BLUDB'

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA LIMIT 5;
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(3512276, 'HK587712', '08/28/2004 05:50:56 PM', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, '02/10/2018 03:50:01 PM', Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '06/26/2004 12:40:00 PM', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, '02/28/2018 03:56:25 PM', Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
# ...

# %% [markdown]
# ## Problem 1
#
# Find the total number of crimes recorded in the crime table.

# %%
# %sql SELECT COUNT(id) DISTINCT FROM CHICAGO_CRIME_DATA;
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %%
# %sql SELECT COUNT(case_number) DISTINCT FROM CHICAGO_CRIME_DATA;
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %% [markdown]
# ## Problem 2
# Retrieve first 10 rows from the CRIME table.

# %%
# %sql SELECT * FROM CHICAGO_CRIME_DATA LIMIT 10;
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(3512276, 'HK587712', '08/28/2004 05:50:56 PM', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, '02/10/2018 03:50:01 PM', Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '06/26/2004 12:40:00 PM', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, '02/28/2018 03:56:25 PM', Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
# ...

# %% [markdown]
# ## Problem 3
# How many crimes involve an arrest.

# %%
# %sql SELECT COUNT(arrest) FROM CHICAGO_CRIME_DATA WHERE arrest = 'TRUE';
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('163'),)]

# %% [markdown]
# ## Problem 4
# Which unique types of crimes (e.g. THEFT) have been recorded at a GAS STATION locations?

# %%
# %sql SELECT DISTINCT primary_type FROM CHICAGO_CRIME_DATA WHERE location_description = 'GAS STATION';
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('CRIMINAL TRESPA',), ('NARCOTICS',), ('ROBBERY',), ('THEFT',)]

# %% [markdown]
# ## Problem 5
# In the CENSUS_DATA table list all community areas whose names start with the letter ‘B’.

# %%
# %sql SELECT community_area_name FROM CENSUS_DATA WHERE community_area_name LIKE 'B%'
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Belmont Cragin',),
#  ('Burnside',),
#  ('Brighton Park',),
#  ('Bridgeport',),
#  ('Beverly',)]

# %% [markdown]
# ## Problem 6
# List the schools in community areas 10 to 15 that are healthy school certified.

# %%
# %sql SELECT name_of_school FROM CHICAGO_PUBLIC_SCHOOLS \
    WHERE (community_area_number BETWEEN 10 AND 15) AND healthy_school_certified = 'Yes';
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Rufus M Hitch Elementary School',)]

# %% [markdown]
# ## Problem 7
# What is the average school Safety Score?

# %%
# %sql SELECT AVG(safety_score) FROM CHICAGO_PUBLIC_SCHOOLS;
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('49.504873'),)]

# %% [markdown]
# ## Problem 8
# Find the top 5 Community Areas by average College Enrollment [number of students].

# %%
# %sql select community_area_name FROM CHICAGO_PUBLIC_SCHOOLS \
WHERE college_enrollment > (SELECT AVG(college_enrollment) FROM CHICAGO_PUBLIC_SCHOOLS) \
ORDER BY college_enrollment DESC \
LIMIT 5;
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('NORTH CENTER',),
#  ('ARCHER HEIGHTS',),
#  ('NORWOOD PARK',),
#  ('BRIGHTON PARK',),
#  ('IRVING PARK',)]

# %% [markdown]
# ## Problem 9
# Use a sub-query to determine which Community Area has the least value for school Safety Score

# %%
# %sql SELECT community_area_name FROM CHICAGO_PUBLIC_SCHOOLS \
WHERE safety_score = \
    (SELECT MIN(safety_score) FROM CHICAGO_PUBLIC_SCHOOLS)
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK',)]

# %% [markdown]
# ## Problem 10
# [Without using an explicit JOIN operator] Find the Per Capita Income of the Community Area which has a school Safety Score of 1.

# %%
# %sql SELECT CHICAGO_PUBLIC_SCHOOLS.community_area_name, CENSUS_DATA.per_capita_income, CHICAGO_PUBLIC_SCHOOLS.safety_score \
FROM CENSUS_DATA, CHICAGO_PUBLIC_SCHOOLS \
WHERE CHICAGO_PUBLIC_SCHOOLS.safety_score = 1;
# per_capita_income
# Out:
#  * ibm_db_sa://lfq69032:***@dashdb-txn-sbox-yp-lon02-02.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK', 23939, 1),
#  ('WASHINGTON PARK', 23040, 1),
#  ('WASHINGTON PARK', 35787, 1),
#  ('WASHINGTON PARK', 37524, 1),
#  ('WASHINGTON PARK', 57123, 1),
#  ('WASHINGTON PARK', 60058, 1),
#  ('WASHINGTON PARK', 71551, 1),
#  ('WASHINGTON PARK', 88669, 1),
#  ('WASHINGTON PARK', 40959, 1),
#  ('WASHINGTON PARK', 32875, 1),
#  ('WASHINGTON PARK', 27751, 1),
#  ('WASHINGTON PARK', 44164, 1),
#  ('WASHINGTON PARK', 26576, 1),
#  ('WASHINGTON PARK', 21323, 1),
#  ('WASHINGTON PARK', 24336, 1),
#  ('WASHINGTON PARK', 27249, 1),
#  ('WASHINGTON PARK', 26282, 1),
#  ('WASHINGTON PARK', 22014, 1),
#  ('WASHINGTON PARK', 15461, 1),
#  ('WASHINGTON PARK', 15089, 1),
#  ('WASHINGTON PARK', 20039, 1),
#  ('WASHINGTON PARK', 31908, 1),
#  ('WASHINGTON PARK', 13781, 1),
#  ('WASHINGTON PARK', 43198, 1),
#  ('WASHINGTON PARK', 15957, 1),
#  ('WASHINGTON PARK', 10934, 1),
# ...
